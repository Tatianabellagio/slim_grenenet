# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import math 
import os

import matplotlib.pyplot as plt

import allel
import subprocess

# %%
pd.read_csv('chr5_grenenet_filteredmaf.prune.in.txt')
# Out:
#               5_53
# 0             5_62
# 1             5_71
# 2            5_116
# 3            5_134
# 4            5_140
# ...            ...
# 218239  5_26975121
# 218240  5_26975144
# 218241  5_26975271
# 218242  5_26975272
# 218243  5_26975288
#
# [218244 rows x 1 columns]

# %%
positions_to_filter = pd.read_csv('chr5_grenenet_filteredmaf.prune.in.txt',header=None)[0].str.split('_').str[1]

# %%
positions_to_filter.to_csv('prune.in.txt',index=None,header=None)

# %%
len(positions_to_filter)
# Out:
# 218245

# %%
positions_to_filter
# Out:
# 0              135
# 1              198
# 2              207
# 3              219
# 4              296
#             ...
# 348856    26975053
# 348857    26975078
# 348858    26975148
# 348859    26975206
# 348860    26975208
# Name: 0, Length: 348861, dtype: object

# %%
pd.read_csv('../test/arq_pi0.001_beta5_allele_counts.csv', index_col=0,nrows=10)
# Out:
#       ref_optima10_subp6.vcf  alt_optima10_subp6.vcf  ref_optima10_subp1.vcf
# 62                     370.0                    24.0                   224.0  \
# 188                    370.0                    24.0                   224.0
# 269                     24.0                   370.0                    10.0
# 450                    370.0                    24.0                   224.0
# 516                      0.0                   394.0                     0.0
# 590                      0.0                   394.0                     0.0
# 591                    370.0                    24.0                   224.0
# 604                     24.0                   370.0                    10.0
# 793                     24.0                   370.0                    10.0
# 1155                     0.0                   394.0                     0.0
#
#       alt_optima10_subp1.vcf  ref_optima10_subp8.vcf  alt_optima10_subp8.vcf
# ...

# %%
filter_test = [1,2]

# %%
pd.read_csv('../test/arq_pi0.001_beta5_allele_counts.csv',nrows=10, index_col=0, skiprows=filter_test)
# Out:
#       ref_optima10_subp6.vcf  alt_optima10_subp6.vcf  ref_optima10_subp1.vcf
# 269                     24.0                   370.0                    10.0  \
# 450                    370.0                    24.0                   224.0
# 516                      0.0                   394.0                     0.0
# 590                      0.0                   394.0                     0.0
# 591                    370.0                    24.0                   224.0
# 604                     24.0                   370.0                    10.0
# 793                     24.0                   370.0                    10.0
# 1155                     0.0                   394.0                     0.0
# 1168                     0.0                   394.0                     0.0
# 1291                     0.0                   394.0                     0.0
#
#       alt_optima10_subp1.vcf  ref_optima10_subp8.vcf  alt_optima10_subp8.vcf
# ...

# %%
allele_counts = pd.read_csv('../test/arq_pi0.001_beta5_allele_counts.csv', index_col=0, skiprows=lambda x: x in positions_to_filter)
## this file initially had 643749

# %%
26975053 in allele_counts.index
# Out:
# True

# %%
allele_counts.iloc[26975053, :]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 allele_counts.iloc[26975053, :]
#
# File ~/mambaforge/envs/pipeline_slim/lib/python3.9/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~/mambaforge/envs/pipeline_slim/lib/python3.9/site-packages/pandas/core/indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# ...

# %%
len(positions_to_filter)
# Out:
# 348861

# %%
positions_to_keep = pd.read_csv('chr5_grenenet_filteredmaf.prune.in',header=None)[0].str.split('_').str[1]

# %%
all_pos = pd.read_csv('../test/arq_pi0.001_beta5_allele_counts.csv', index_col=0,usecols=[0,1]).reset_index() # ['index'].astype(int).tolist()

# %%
filtered_df_python = all_pos[all_pos['index'].isin(positions_to_keep.astype(int))]

# %%
filtered_df_python = filtered_df_python['index'].reset_index(drop=True)

# %%
filtered_df_awk = pd.read_csv('filtered.csv',header=None)

# %%
filtered_df_python
# Out:
# 0               62
# 1              188
# 2              269
# 3              591
# 4             1155
#             ...
# 183536    26866522
# 183537    26917201
# 183538    26933021
# 183539    26938514
# 183540    26958541
# Name: index, Length: 183541, dtype: int64

# %%
filtered_df_awk
# Out:
#              0      1      2      3      4      5      6      7      8
# 0             62  370.0   24.0  224.0   10.0  352.0   14.0  340.0   60.0  \
# 1            188  370.0   24.0  224.0   10.0  352.0   14.0  340.0   60.0
# 2            269   24.0  370.0   10.0  224.0   14.0  352.0   60.0  340.0
# 3            591  370.0   24.0  224.0   10.0  352.0   14.0  340.0   60.0
# 4           1155    0.0  394.0    0.0  234.0    0.0  366.0    0.0  400.0
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 183536  26866522  197.0    0.0  117.0    0.0  183.0    0.0  200.0    0.0
# 183537  26917201  197.0    0.0  117.0    0.0  183.0    0.0  200.0    0.0
# 183538  26933021  197.0    0.0  117.0    0.0  183.0    0.0  200.0    0.0
# 183539  26938514  197.0    0.0  117.0    0.0  183.0    0.0  200.0    0.0
# 183540  26958541  197.0    0.0  117.0    0.0  183.0    0.0  200.0    0.0
#
#           9    ...    351    352    353    354    355    356    357    358
# ...

# %%
(filtered_df_awk[0] == filtered_df_python).all()
# Out:
# True
