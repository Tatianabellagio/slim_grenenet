# %%
# once i have wholegenome_offset.trees
import pandas as pd
import tskit
import allel
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tsinfer
import pyslim
import os
from collections import defaultdict

# %%
import glob

path2 = '/home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/'


# Use the glob module to search for files in subfolders
pattern = os.path.join(path2, '**', '*_pop_size.txt')
pop_size_files = glob.glob(pattern, recursive=True)

# %%
def arrange_dataset(files):
    joint = pd.DataFrame()
    for i in files:
        one_file = pd.read_csv(i,header=None)
        one_file.columns = [i]
        joint = pd.concat([joint, one_file],axis=1)
    joint = joint.T
    joint.index = joint.index.str.split('/subp').str[0]
    #joint_meansubp = joint.reset_index().groupby('index')[joint.columns].mean()
    return joint

# %%
pop_size = arrange_dataset(pop_size_files)

# %%
# Use the glob module to search for files in subfolders
pattern = os.path.join(path2, '**', '*_va.txt')
va_files = glob.glob(pattern, recursive=True)

# %%
va = arrange_dataset(va_files)

# %%
# Use the glob module to search for files in subfolders
pattern = os.path.join(path2, '**', '*_vpheno.txt')
vpheno_files = glob.glob(pattern, recursive=True)

# %%
vpheno = arrange_dataset(vpheno_files)

# %%
# Use the glob module to search for files in subfolders
pattern = os.path.join(path2, '**', '*_mfitness.txt')
mfitness_files = glob.glob(pattern, recursive=True)

# %%
mfitness = arrange_dataset(mfitness_files)

# %%
# Use the glob module to search for files in subfolders
pattern = os.path.join(path2, '**', '*_vfitness.txt')
vfitness_files = glob.glob(pattern, recursive=True)

# %%
vfitness = arrange_dataset(vfitness_files)

# %%
va.to_csv('results_va10gen.csv')
vpheno.to_csv('results_vpheno10gen.csv')
mfitness.to_csv('results_mfitness10gen.csv')
vfitness.to_csv('results_vfitness10gen.csv')
pop_size.to_csv('results_pop_size10gen.csv')

# %%
sns.set_theme(style="white")
rs = np.random.RandomState(50)

# Set up the matplotlib figure
f, axes = plt.subplots(3, 3, figsize=(9, 9), sharex=True, sharey=True)

# Rotate the starting point around the cubehelix hue circle
for ax, s in zip(axes.flat, np.linspace(0, 3, 10)):

    # Create a cubehelix colormap to use with kdeplot
    cmap = sns.cubehelix_palette(start=s, light=1, as_cmap=True)

    # Generate and plot a random bivariate dataset
    x, y = rs.normal(size=(2, 50))
    sns.kdeplot(
        x=x, y=y,
        cmap=cmap, fill=True,
        clip=(-5, 5), cut=10,
        thresh=0, levels=15,
        ax=ax,
    )
    ax.set_axis_off()

ax.set(xlim=(-3.5, 3.5), ylim=(-3.5, 3.5))
f.subplots_adjust(0, 0, 1, 1, .08, .08)

# %%
mfitness
# Out:
#                                                            0         1  \
# index
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.169039       NaN
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.352795  0.449871
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.517744  0.615151
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.532102  0.578985
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.390618  0.486118
# ...                                                      ...       ...
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.028845       NaN
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.089379       NaN
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.185396       NaN
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.221572       NaN
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0.113237       NaN
#
#                                                            2         3  \
# index
# ...

# %%
mfitness['optima'] = mfitness.index.str.split('/').str[-1]
mfitness['sel'] = mfitness.index.str.split('/').str[-2]
mfitness['freq'] = mfitness.index.str.split('/').str[-3].str.split('_').str[1]
mfitness['poly'] = mfitness.index.str.split('/').str[-3].str.split('_').str[2]
mfitness['beta'] = mfitness.index.str.split('/').str[-3].str.split('_').str[3]

# %%
mfitness_0gen= mfitness[['optima','sel','freq','poly','beta', 0]].copy()

# %%
mfitness_0gen = mfitness_0gen.reset_index(drop=True)

# %%
mfitness_0gen = mfitness_0gen.rename(columns={1: 'mfitness_1gen'})

# %%
mfitness_1gen= mfitness[['optima','sel','freq','poly','beta', 1]].copy()

# %%
mfitness_1gen = mfitness_1gen.reset_index(drop=True)

# %%
mfitness_1gen = mfitness_1gen.rename(columns={1: 'mfitness_1gen'})

# %%
poly_freq = mfitness_1gen[['poly', 'freq','mfitness_1gen']]

# %%
sns.kdeplot(
        x=x, y=y,
        cmap=cmap, fill=True,
        clip=(-5, 5), cut=10,
        thresh=0, levels=15,
        ax=ax,
    )

# %%
poly_freq = poly_freq.fillna(0)

# %%
poly_freq
# Out:
#            poly        freq  mfitness_1gen
# 0      fivepoly    highfreq       0.000000
# 1      fivepoly    highfreq       0.449871
# 2      fivepoly    highfreq       0.615151
# 3      fivepoly    highfreq       0.578985
# 4      fivepoly    highfreq       0.486118
# ..          ...         ...            ...
# 355  twentypoly  mediumfreq       0.000000
# 356  twentypoly  mediumfreq       0.000000
# 357  twentypoly  mediumfreq       0.000000
# 358  twentypoly  mediumfreq       0.000000
# 359  twentypoly  mediumfreq       0.000000
#
# [360 rows x 3 columns]

# %%
g = sns.FacetGrid(poly_freq, col='freq', row='poly', margin_titles=True)
g.map(sns.kdeplot, 'mfitness_1gen', cmap=cmap, fill=True,
        clip=(-5, 5), cut=10,
        thresh=0, levels=15,)
# Adjust layout
g.fig.tight_layout()
# Show the plot
plt.show()
# Out:
# /home/tbellagio/mambaforge/envs/pipeline_snakemake/lib/python3.9/site-packages/seaborn/axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)

# %%
poly_freq
# Out:
#            poly        freq  mfitness_1gen             identifier
# 0      fivepoly    highfreq       0.000000      fivepoly_highfreq
# 1      fivepoly    highfreq       0.449871      fivepoly_highfreq
# 2      fivepoly    highfreq       0.615151      fivepoly_highfreq
# 3      fivepoly    highfreq       0.578985      fivepoly_highfreq
# 4      fivepoly    highfreq       0.486118      fivepoly_highfreq
# ..          ...         ...            ...                    ...
# 355  twentypoly  mediumfreq       0.000000  twentypoly_mediumfreq
# 356  twentypoly  mediumfreq       0.000000  twentypoly_mediumfreq
# 357  twentypoly  mediumfreq       0.000000  twentypoly_mediumfreq
# 358  twentypoly  mediumfreq       0.000000  twentypoly_mediumfreq
# 359  twentypoly  mediumfreq       0.000000  twentypoly_mediumfreq
#
# [360 rows x 4 columns]

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=poly_freq, x='poly', y='mfitness_1gen', hue='freq')
plt.title('Comparison of Values by Categorical Variables')
plt.xlabel('Category1')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
mfitness_1gen
# Out:
#       optima        sel        freq        poly      beta  mfitness_1gen
# 0    optima0     lowsel    highfreq    fivepoly  highbeta            NaN
# 1    optima1     lowsel    highfreq    fivepoly  highbeta       0.449871
# 2    optima2     lowsel    highfreq    fivepoly  highbeta       0.615151
# 3    optima3     lowsel    highfreq    fivepoly  highbeta       0.578985
# 4    optima4     lowsel    highfreq    fivepoly  highbeta       0.486118
# ..       ...        ...         ...         ...       ...            ...
# 355  optima0  strongsel  mediumfreq  twentypoly   lowbeta            NaN
# 356  optima1  strongsel  mediumfreq  twentypoly   lowbeta            NaN
# 357  optima2  strongsel  mediumfreq  twentypoly   lowbeta            NaN
# 358  optima3  strongsel  mediumfreq  twentypoly   lowbeta            NaN
# 359  optima4  strongsel  mediumfreq  twentypoly   lowbeta            NaN
#
# [360 rows x 6 columns]

# %%
# Create a facet grid with one additional categorical variable mapped to color
g = sns.catplot(data=df, x='Category1', y='Values', hue='Category2', col='Category3',
                row='Category4', kind='box', height=4, aspect=1.5, palette='Set1')
g.fig.suptitle('Comparison of Values by Categorical Variables', y=1.02)
g.set_axis_labels('Category1', 'Values')

# Show the plot
plt.show()

# %%
mfitness_1gen['freq'].unique()
# Out:
# array(['highfreq', 'lowfreq', 'mediumfreq'], dtype=object)

# %%
custom_categories = ['lowfreq', 'mediumfreq', 'highfreq']
custom_colors = sns.color_palette("Greens", n_colors=len(custom_categories))

# Create a custom color dictionary
custom_color_dict = dict(zip(custom_categories, custom_colors))

# Example DataFrame (replace with your actual DataFrame)
# df = ...

# Map the custom colors to the 'hue' variable using the custom dictionary
#df['CustomColor'] = df['Category2'].map(custom_color_dict)

# %%
import itertools
import seaborn as sns

# %%
# Define the custom color palette with 3 colors
custom_colors = sns.color_palette("Greens", n_colors=3)

# Repeat the custom palette 5 times, alternating between light and dark
#repeated_colors = list(itertools.chain.from_iterable(itertools.cycle(custom_colors) for _ in range(5)))

# %%
print(custom_colors)
# Out:
# [(0.7792233756247597, 0.9132333717800846, 0.7518031526336024), (0.45176470588235296, 0.7670895809304115, 0.4612072279892349), (0.1340253748558247, 0.5423298731257208, 0.26828143021914647)]

# %%
hue_order = ['lowfreq_optima0', 'lowfreq_optima1', 'lowfreq_optima2',
       'lowfreq_optima3', 'lowfreq_optima4', 'mediumfreq_optima0', 'mediumfreq_optima1',
       'mediumfreq_optima2', 'mediumfreq_optima3', 'mediumfreq_optima4','highfreq_optima0',
       'highfreq_optima1', 'highfreq_optima2', 'highfreq_optima3',
       'highfreq_optima4']

# %%
[i * 3 for i in custom_colors]
# Out:
# [(0.7792233756247597,
#   0.9132333717800846,
#   0.7518031526336024,
#   0.7792233756247597,
#   0.9132333717800846,
#   0.7518031526336024,
#   0.7792233756247597,
#   0.9132333717800846,
#   0.7518031526336024),
#  (0.45176470588235296,
#   0.7670895809304115,
#   0.4612072279892349,
#   0.45176470588235296,
#   0.7670895809304115,
#   0.4612072279892349,
#   0.45176470588235296,
#   0.7670895809304115,
#   0.4612072279892349),
#  (0.1340253748558247,
#   0.5423298731257208,
#   0.26828143021914647,
#   0.1340253748558247,
#   0.5423298731257208,
#   0.26828143021914647,
#   0.1340253748558247,
#   0.5423298731257208,
#   0.26828143021914647)]

# %%
colors = [(0.7792233756247597,
  0.9132333717800846,
  0.7518031526336024),
  (0.7792233756247597,
  0.9132333717800846,
  0.7518031526336024),
  (0.7792233756247597,
  0.9132333717800846,
  0.7518031526336024),
 (0.45176470588235296,
  0.7670895809304115,
  0.4612072279892349),
  (0.45176470588235296,
  0.7670895809304115,
  0.4612072279892349),
  (0.45176470588235296,
  0.7670895809304115,
  0.4612072279892349),
 (0.1340253748558247,
  0.5423298731257208,
  0.26828143021914647),
  (0.1340253748558247,
  0.5423298731257208,
  0.26828143021914647),
  (0.1340253748558247,
  0.5423298731257208,
  0.26828143021914647)]

# %%
res = {custom_categories[i]: custom_colors[i] for i in range(len(custom_colors))}

# %%
mfitness_1gen['freq'].unique()
# Out:
# array(['highfreq', 'lowfreq', 'mediumfreq'], dtype=object)

# %%
hue_order= [ 'lowfreq', 'mediumfreq', 'highfreq']

# %%
palette=custom_colors

# %%
# Create a facet grid with two additional categorical variables
g = sns.catplot(data=mfitness_1gen, x='sel', y='mfitness_1gen', hue='freq', col='beta', row='poly',
                row_order=['monogen', 'fivepoly', 'twentypoly', 'onehpoly'], 
                kind="boxen", height=4, aspect=1.5,
                palette=res,
                hue_order=hue_order)
g.fig.suptitle('Mean Fitness 1st gen', y=1.02)
g.set_axis_labels('selection strength', 'mean fitness')

# Show the plot
plt.show()

# %%
mfitness_0gen[mfitness_0gen[0]>1]
# Out:
# Empty DataFrame
# Columns: [optima, sel, freq, poly, beta, 0]
# Index: []

# %%
mfitness_0gen['freq-optima'] = mfitness_0gen['freq'] + '_' +  mfitness_0gen['optima']

# %%
mfitness_0gen['freq-optima'].unique()
# Out:
# array(['lowfreq_optima4', 'lowfreq_optima3', 'lowfreq_optima0',
#        'lowfreq_optima2', 'lowfreq_optima1', 'highfreq_optima0',
#        'highfreq_optima4', 'highfreq_optima3', 'highfreq_optima1',
#        'highfreq_optima2', 'mediumfreq_optima2', 'mediumfreq_optima1',
#        'mediumfreq_optima3', 'mediumfreq_optima4', 'mediumfreq_optima0'],
#       dtype=object)

# %%
hue_order = ['lowfreq_optima0', 'lowfreq_optima1', 'lowfreq_optima2',
       'lowfreq_optima3', 'lowfreq_optima4', 'mediumfreq_optima0', 'mediumfreq_optima1',
       'mediumfreq_optima2', 'mediumfreq_optima3', 'mediumfreq_optima4','highfreq_optima0',
       'highfreq_optima1', 'highfreq_optima2', 'highfreq_optima3',
       'highfreq_optima4']

# %%
import itertools

# %%
custom_colors = sns.color_palette("Greens", n_colors=3)

# Repeat the custom palette 5 times, alternating between light and dark
repeated_colors = list(itertools.chain.from_iterable(itertools.cycle(custom_colors) for _ in range(5)))

# %%
repeated_colors

# %%
custom_categories = ['lowfreq', 'mediumfreq', 'highfreq']
custom_colors = sns.color_palette("Greens", n_colors=len(hue_order))

# Create a custom color dictionary
custom_color_dict = dict(zip(custom_categories, custom_colors))

# %%
# Create a facet grid with two additional categorical variables
g = sns.catplot(data=mfitness_0gen, x='sel', y=0, hue='freq-optima', col='beta', row='poly',
                row_order=['monogen', 'fivepoly', 'twentypoly', 'onehpoly'], 
                kind="swarm", height=4, aspect=1.5,
                palette=res,
                hue_order=hue_order)
g.fig.suptitle('Mean Fitness 0st gen', y=1.02)
g.set_axis_labels('selection strength', 'mean fitness')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 2
#       1 # Create a facet grid with two additional categorical variables
# ----> 2 g = sns.catplot(data=mfitness_0gen, x='sel', y=0, hue='freq-optima', col='beta', row='poly',
#       3                 row_order=['monogen', 'fivepoly', 'twentypoly', 'onehpoly'],
#       4                 kind="swarm", height=4, aspect=1.5,
#       5                 palette=res,
#       6                 hue_order=hue_order)
#       7 g.fig.suptitle('Mean Fitness 0st gen', y=1.02)
#       8 g.set_axis_labels('selection strength', 'mean fitness')
#
# ...

# %%
# Create a facet grid with two additional categorical variables
g = sns.catplot(data=mfitness_0gen, x='sel', y=0, hue='freq', col='beta', row='poly',
                row_order=['monogen', 'fivepoly', 'twentypoly', 'onehpoly'], 
                kind="violin", height=4, aspect=1.5,
                palette=res,
                hue_order=hue_order)
g.fig.suptitle('Mean Fitness 0st gen', y=1.02)
g.set_axis_labels('selection strength', 'mean fitness')

# Show the plot
plt.show()

# %%
dead
# Out:
# index
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_highfreq_fivepoly_highbeta/lowsel/optima0          8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_highfreq_fivepoly_highbeta/lowsel/optima1          0
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_highfreq_fivepoly_highbeta/lowsel/optima2          0
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_highfreq_fivepoly_highbeta/lowsel/optima3          0
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_highfreq_fivepoly_highbeta/lowsel/optima4          0
#                                                                                                                       ..
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_mediumfreq_twentypoly_lowbeta/strongsel/optima0    8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/results/arq_mediumfreq_twentypoly_lowbeta/strongsel/optima1    8
# ...

# %%
dead = dead.reset_index().set_index('index')

# %%
dead[(dead[0]!=8) & (dead[0]!=0) ]
# Out:
#                                                     0
# index
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  7

# %%
sns.heatmap(dead)
# Out:
# <Axes: ylabel='index'>

# %%
# Out:
#                                                     0
# index
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  0
# ...                                                ..
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  8
# /home/tbellagio/scratch/slim_grenenet4gen/slim_...  8
#
# [360 rows x 1 columns]

# %%
survival = pop_size[8].isna().replace({True: 1, False: 0})

# %%
survival.name = 'survival'

# %%
survival = survival.reset_index()

# %%
survival['optima'] = survival['index'].str.split('/').str[-1]

# %%
survival['sel'] = survival['index'].str.split('/').str[-2]

# %%
survival['freq'] = survival['index'].str.split('_').str[-3]

# %%
survival['poly'] = survival['index'].str.split('_').str[-2]

# %%
survival['beta'] = survival['index'].str.split('_').str[-1].str.split('/').str[0]

# %%
survival = survival.drop('index',axis=1)

# %%
## maybe is a good idea to replace optima by extreme, mod and intermediate?

# %%
survival = survival.replace({'optima0': 2, 'optima1': 1, 'optima2': 0, 'optima3': 1, 'optima4': 2})

# %%
survival = survival.replace({'lowsel': 0, 'moderatesel': 1, 'strongsel': 2})

# %%
survival = survival.replace({'lowfreq': 0, 'mediumfreq': 1, 'highfreq': 2})

# %%
survival = survival.replace({'monogen': 1, 'fivepoly': 5, 'twentypoly': 20, 'onehpoly':100})

# %%
survival = survival.replace({'highbeta': 1, 'lowbeta': 0})

# %%
sklearn.preprocessing.OneHotEncoder or pandas.get_dummies

# %%
survival
# Out:
#      survival  optima  sel  freq  poly  beta
# 0           1       2    0     2     5     1
# 1           0       1    0     2     5     1
# 2           0       0    0     2     5     1
# 3           0       1    0     2     5     1
# 4           0       2    0     2     5     1
# ..        ...     ...  ...   ...   ...   ...
# 355         1       2    2     1    20     0
# 356         1       1    2     1    20     0
# 357         1       0    2     1    20     0
# 358         1       1    2     1    20     0
# 359         1       2    2     1    20     0
#
# [360 rows x 6 columns]

# %%
X.columns
# Out:
# Index(['optima', 'sel', 'freq', 'poly', 'beta'], dtype='object')

# %%
X = survival.drop('survival',axis=1)

# %%
Y = survival['survival']

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(max_depth=6)

# %%
clf = clf.fit(X, Y)

# %%
tree.plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names)

# %%
# plot tree
plt.figure(figsize=(20,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, fontsize=10, feature_names = X.columns, class_names=['died', 's'])
plt.show()

# %%
tree.plot_tree(clf);
# Out:
# [Text(0.6247282608695652, 0.95, 'x[3] <= 12.5\ngini = 0.439\nsamples = 360\nvalue = [117, 243]'),
#  Text(0.4016304347826087, 0.85, 'x[1] <= 1.5\ngini = 0.5\nsamples = 180\nvalue = [91, 89]'),
#  Text(0.21195652173913043, 0.75, 'x[0] <= 1.5\ngini = 0.45\nsamples = 120\nvalue = [79, 41]'),
#  Text(0.06956521739130435, 0.65, 'x[1] <= 0.5\ngini = 0.278\nsamples = 72\nvalue = [60, 12]'),
#  Text(0.02608695652173913, 0.55, 'x[3] <= 3.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.017391304347826087, 0.45, 'x[4] <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.008695652173913044, 0.35, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.02608695652173913, 0.35, 'x[2] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.017391304347826087, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.034782608695652174, 0.25, 'x[2] <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
# ...
